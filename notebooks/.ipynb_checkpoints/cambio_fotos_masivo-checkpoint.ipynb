# %% [markdown]
# ## Programa de prueba para cargar imagenes masivamente por codigo CA
#
# Este programa se basa en el codigo CA, con la finalidad de poder cambiar masivamente fotos, sin la necesidad de leer o hacer peticiones masivas o excesivas a el servidor de medios.cardic y a ML, ya que se busca validar unicamente una sola vez una las fotos, y con los ids que ML retorna, vincular multiples publicaciones de golpe.

# %%
import pandas as pd
import numpy as np
import requests
from pymongo import MongoClient

# %% [markdown]
# ### Conexión con nuestra DB masiva
#
# Comenzamos haciendo una conexión con la DB mongo hosteada en railway, donde tenemos un aproximado de 2,534,531 items publicados. Divididos en 5 tiendas oficiales ( CO, DS, TE, TS, CA )

# %%
# URL de conexión proporcionada por railway
uri = "mongodb://mongo:OtqZXbDnLBYZbmYPBQrlSUQlUXiosTgK@mainline.proxy.rlwy.net:35712"

# Crear el cliente
client = MongoClient(uri)

# Probar la conexión listando bases de datos
print("Bases de datos disponibles:")
print(client.list_database_names())
# Out:
# Bases de datos disponibles:
# ['admin', 'config', 'local', 'test']

# %%
# Seleccionamos la DB y la collection de items
db = client["test"]
items_col = db["items"]

# Contabilizamos todos los items por tienda.
print(f"CO: {items_col.count_documents({"origen": "CO"})}")
print(f"DS: {items_col.count_documents({"origen": "DS"})}")
print(f"TE: {items_col.count_documents({"origen": "TE"})}")
print(f"TS: {items_col.count_documents({"origen": "TS"})}")
print(f"CA: {items_col.count_documents({"origen": "CA"})}")
# Out:
# CO: 635859
# DS: 456878
# TE: 538531
# TS: 364346
# CA: 538741

# %%
# Comenzamos a leer el archivo de excel

tiendas_cardic = pd.read_excel("../Data/Fotos_CA/fotos_masivo.xlsx", sheet_name=0)
tiendas_tanak = pd.read_excel("../Data/Fotos_CA/fotos_masivo.xlsx", sheet_name=1)

# %%
tiendas_cardic
# Out:
#          CA                                            IMAGNE1  \
# 0   ALT0318  https://medios.cardic.com.mx/wp-content/upload...
# 1   ALT0462  https://medios.cardic.com.mx/wp-content/upload...
# 2   ALT0463  https://medios.cardic.com.mx/wp-content/upload...
# 3   ALT0459  https://medios.cardic.com.mx/wp-content/upload...
# 4   ALT0357  https://medios.cardic.com.mx/wp-content/upload...
# ..      ...                                                ...
# 80  ALT0387  https://medios.cardic.com.mx/wp-content/upload...
# 81  ALT0388  https://medios.cardic.com.mx/wp-content/upload...
# 82  ALT0500  https://medios.cardic.com.mx/wp-content/upload...
# 83  ALT0297  https://medios.cardic.com.mx/wp-content/upload...
# 84  ALT0417  https://medios.cardic.com.mx/wp-content/upload...
#
#                                               IMAGNE2  \
# 0   https://medios.cardic.com.mx/wp-content/upload...
# 1   https://medios.cardic.com.mx/wp-content/upload...
# ...

# %%
tiendas_tanak
# Out:
#          CA                                            IMAGNE1  \
# 0   ALT0318  https://medios.cardic.com.mx/wp-content/upload...
# 1   ALT0462  https://medios.cardic.com.mx/wp-content/upload...
# 2   ALT0463  https://medios.cardic.com.mx/wp-content/upload...
# 3   ALT0459  https://medios.cardic.com.mx/wp-content/upload...
# 4   ALT0357  https://medios.cardic.com.mx/wp-content/upload...
# ..      ...                                                ...
# 80  ALT0387  https://medios.cardic.com.mx/wp-content/upload...
# 81  ALT0388  https://medios.cardic.com.mx/wp-content/upload...
# 82  ALT0500  https://medios.cardic.com.mx/wp-content/upload...
# 83  ALT0297  https://medios.cardic.com.mx/wp-content/upload...
# 84  ALT0417  https://medios.cardic.com.mx/wp-content/upload...
#
#                                               IMAGNE2  \
# 0   https://medios.cardic.com.mx/wp-content/upload...
# 1   https://medios.cardic.com.mx/wp-content/upload...
# ...

# %% [markdown]
# ### Lectura de tokens
#
# Ahora que ya tenemos cargada toda la información vamos a cargar los tokens y datos necesarios para comunicarnos con mercado libre ademas de generar las funciones necesarias para hacer el refresh del token.

# %%
aplicaciones = db["aplicaciones"]
aplicacion_co = aplicaciones.find_one({"origen": "CO"})
# Leemos la primera aplicación para validar la lectura correcta

print(aplicacion_co.get("client_secret"))
print(aplicacion_co.get("token"))
print(aplicacion_co.get("refresh_token"))
print(aplicacion_co.get("seller_id"))
# Out:
# cGwWGaBenKJPmvOsM2nRetz9bzHdmOnC
# APP_USR-3438495866141925-100411-bdad2134f116174c3a694c74fbe17255-1190944577
# TG-68e0ebaf12fc490001427a48-1190944577
# 1190944577

# %%
def renovar_token(store):
    url = "https://api.mercadolibre.com/oauth/token"
    payload = {
        "grant_type": "refresh_token",
        "client_id": store["app_id"],
        "client_secret": store["client_secret"],
        "refresh_token": store["refresh_token"]
    }
    try:
        resp = requests.post(url, data=payload)
        resp.raise_for_status()
        data = resp.json()
        store["access_token"] = data["access_token"]
        store["refresh_token"] = data["refresh_token"]
        print(f"[{store['origen']}] Token renovado {data["access_token"]}")
        return True
    except Exception as e:
        print(f"[{store['origen']}] ERROR renovar token: {e}")
        return False

# %%
origen = "CO"
aplicacion = aplicaciones.find_one({"origen": origen})
renovar_token(aplicacion)
ACCESS_TOKEN = aplicacion.get("token")
# Out:
# [CO] Token renovado APP_USR-3438495866141925-100414-c83cd14bbe2bb1c4159dd024577f23e2-1190944577

# %%
# -----------------------------
# Funciones auxiliares
# -----------------------------
def descargar_imagen(url):
    """Descarga la imagen desde un link y devuelve el contenido en bytes"""
    try:
        resp = requests.get(url, timeout=20, stream=True)
        if resp.status_code == 200:
            return resp.content
        else:
            print(f"❌ Error al descargar {url}: {resp.status_code}")
            return None
    except Exception as e:
        print(f"❌ Excepción descargando {url}: {e}")
        return None

def subir_imagen_ml(imagen_bytes):
    """Sube una imagen a Mercado Libre y devuelve el id"""
    try:
        files = {'file': ('imagen.jpg', imagen_bytes)}
        headers = {"Authorization": f"Bearer {ACCESS_TOKEN}"}
        url = "https://api.mercadolibre.com/pictures/items/upload"
        resp = requests.post(url, headers=headers, files=files, timeout=30)
        if resp.status_code in (200, 201):
            data = resp.json()
            return data.get("id")
        else:
            print(f"❌ Error subiendo imagen a ML: {resp.status_code} - {resp.text[:200]}")
            return None
    except Exception as e:
        print(f"❌ Excepción subiendo imagen a ML: {e}")
        return None

def actualizar_item_ml(item_id, picture_ids):
    """Actualiza el item en ML con las imágenes subidas"""
    try:
        url = f"https://api.mercadolibre.com/items/{item_id}"
        headers = {
            "Authorization": f"Bearer {ACCESS_TOKEN}",
            "Content-Type": "application/json",
            "Accept": "application/json"
        }
        payload = {"pictures": [{"id": pid} for pid in picture_ids]}
        resp = requests.put(url, headers=headers, json=payload, timeout=30)
        if resp.status_code == 200:
            print(f"✅ Item {item_id} actualizado con {len(picture_ids)} imágenes.")
        else:
            print(f"❌ Error actualizando item {item_id}: {resp.status_code} - {resp.text[:200]}")
    except Exception as e:
        print(f"❌ Excepción actualizando item {item_id}: {e}")

def validar_url(url):
    """Valida que la URL exista y sea una imagen"""
    if not url or pd.isna(url):
        return False
    try:
        resp = requests.head(url, timeout=10, allow_redirects=True)
        if resp.status_code in (200, 206) and resp.headers.get("Content-Type", "").startswith("image"):
            return True
        else:
            return False
    except:
        return False

# %%
from time import sleep

# -----------------------------
# Flujo principal
# -----------------------------
for index, row in tiendas_cardic.iterrows():
    ca = row["CA"].strip()
    print(f"\n🔹 Procesando CA: {ca}")

    # Buscar items en MongoDB que tengan el CA en seller_custom_sku y el origen correcto
    query = {"seller_custom_sku": {"$regex": ca}, "origen": origen}
    items = list(items_col.find(query))
    item_ids = [str(item["_id"]) for item in items]
    print(f"📦 Se encontraron {len(item_ids)} items para {ca}")

    # Recopilar todas las imágenes del row
    picture_columns = [f"IMAGNE{i}" for i in range(1, 11)]
    picture_ids = []

    for col in picture_columns:
        url = row.get(col)
        if url and validar_url(url):
            img_bytes = descargar_imagen(url)
            if img_bytes:
                pic_id = subir_imagen_ml(img_bytes)
                if pic_id:
                    picture_ids.append(pic_id)
        elif url:
            print(f"⚠️ URL inválida o inaccesible: {url}")

    # Asignar las imágenes a cada item
    for item_id in item_ids:
        if picture_ids:
            actualizar_item_ml(item_id, picture_ids)
            sleep(0.5)
        else:
            print(f"⚠️ No hay imágenes válidas para asignar al item {item_id}")

print("\n🎉 Proceso finalizado para todos los CA.")
# Out:
# 🔹 Procesando CA: ALT0318
# 📦 Se encontraron 162 items para ALT0318
# ⚠️ URL inválida o inaccesible: nan
# ⚠️ URL inválida o inaccesible: nan
# ⚠️ URL inválida o inaccesible: nan
# ✅ Item MLM1711866287 actualizado con 7 imágenes.
# ✅ Item MLM2133596463 actualizado con 7 imágenes.
# ✅ Item MLM2133596461 actualizado con 7 imágenes.
# ✅ Item MLM2133596601 actualizado con 7 imágenes.
# ✅ Item MLM2133596549 actualizado con 7 imágenes.
# ✅ Item MLM2133596471 actualizado con 7 imágenes.
# ✅ Item MLM2133596483 actualizado con 7 imágenes.
# ✅ Item MLM2133596609 actualizado con 7 imágenes.
# ✅ Item MLM2133596481 actualizado con 7 imágenes.
# ✅ Item MLM2133596547 actualizado con 7 imágenes.
# ✅ Item MLM2133596469 actualizado con 7 imágenes.
# ✅ Item MLM2133593071 actualizado con 7 imágenes.
# ✅ Item MLM2133593089 actualizado con 7 imágenes.
# ✅ Item MLM2133584011 actualizado con 7 imágenes.
# ✅ Item MLM2133583985 actualizado con 7 imágenes.
# ✅ Item MLM2133593161 actualizado con 7 imágenes.
# ...
